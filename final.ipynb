# %% [markdown]
# CDCDiab Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import os
import sys
from io import StringIO

# %%
#dfs =allFiles
#from functools import reduce
#df_final = reduce(lambda left,right: pd.merge(left,right,on='SEQN', how='outer'), dfs)
# one repate file named SSHCV_E is present in both 07-08 and 09-10 year.

path = 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab\\QuestData\\all'
allFiles = glob.glob(os.path.join(path,"*.xpt"))

data = np.array([np.arange(1,10001)]).T
x_train =pd.DataFrame(data, index = range(0,10000),columns=['SEQN'])

for infile in allFiles:
    df = pd.read_sas(infile)
    df['SEQN']=df['SEQN'].astype(int)
    x_train = x_train.merge(df.drop_duplicates(subset=['SEQN']),on='SEQN', how='left')

# %%
# read the data file form lib. 'TCHOL_I' is for 15-16 and 'TCHOL_H' is 13-14
df1 = pd.read_sas("ALQ_E.XPT")
df2 = pd.read_sas("ACQ_E.XPT")

# %%
df1.isnull().sum()
# Out:
# SEQN          0
# ALQ101      474
# ALQ110     4144
# ALQ120Q    1273
# ALQ120U    2395
# ALQ130     2384
# ALQ140Q    2384
# ALQ140U    4437
# ALQ150     1273
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# SEQN          0
# ACD010A    2355
# ACD010B    7167
# ACD010C    6912
# ACD040     5011
# dtype: int64

# %%
#Merging the Dataset on left joint
left =df2
right=df1
result = pd.merge(left, right, how='left', on=['SEQN', 'SEQN'])

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7173 entries, 0 to 7172
# Data columns (total 13 columns):
# SEQN       7173 non-null float64
# ACD010A    4818 non-null float64
# ACD010B    6 non-null float64
# ACD010C    261 non-null float64
# ACD040     2162 non-null float64
# ALQ101     5233 non-null float64
# ALQ110     1563 non-null float64
# ALQ120Q    4434 non-null float64
# ALQ120U    3312 non-null float64
# ALQ130     3323 non-null float64
# ALQ140Q    3323 non-null float64
# ALQ140U    1270 non-null float64
# ALQ150     4434 non-null float64
# dtypes: float64(13)
# memory usage: 784.5 KB

# %%
df3 = pd.read_sas("ACQ_F.XPT")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7173 entries, 0 to 7172
# Data columns (total 5 columns):
# SEQN       7173 non-null float64
# ACD010A    4818 non-null float64
# ACD010B    6 non-null float64
# ACD010C    261 non-null float64
# ACD040     2162 non-null float64
# dtypes: float64(5)
# memory usage: 280.3 KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7557 entries, 0 to 7556
# Data columns (total 5 columns):
# SEQN       7557 non-null float64
# ACD010A    5001 non-null float64
# ACD010B    15 non-null float64
# ACD010C    375 non-null float64
# ACD040     2280 non-null float64
# dtypes: float64(5)
# memory usage: 295.3 KB

# %%
#Merging the Dataset on left joint
left =df3
right=df2
result = pd.merge(left, right, how='left', on=['SEQN', 'SEQN'])

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7557 entries, 0 to 7556
# Data columns (total 9 columns):
# SEQN         7557 non-null float64
# ACD010A_x    5001 non-null float64
# ACD010B_x    15 non-null float64
# ACD010C_x    375 non-null float64
# ACD040_x     2280 non-null float64
# ACD010A_y    0 non-null float64
# ACD010B_y    0 non-null float64
# ACD010C_y    0 non-null float64
# ACD040_y     0 non-null float64
# dtypes: float64(9)
# memory usage: 590.4 KB

# %%
result.head()
# Out:
#       SEQN  ACD010A_x  ACD010B_x  ACD010C_x  ACD040_x  ACD010A_y  ACD010B_y  \
# 0  51624.0        1.0        NaN        NaN       NaN        NaN        NaN
# 1  51626.0        1.0        NaN        NaN       NaN        NaN        NaN
# 2  51628.0        1.0        NaN        NaN       NaN        NaN        NaN
# 3  51629.0        NaN        NaN        NaN       4.0        NaN        NaN
# 4  51630.0        1.0        NaN        NaN       NaN        NaN        NaN
#
#    ACD010C_y  ACD040_y
# 0        NaN       NaN
# 1        NaN       NaN
# 2        NaN       NaN
# 3        NaN       NaN
# 4        NaN       NaN

# %%
result.to_csv('result.csv')

# %%
dfs = [df3,df2]

from functools import reduce
df_final = reduce(lambda left,right: pd.merge(left,right,on='SEQN', how='outer'), dfs)

# %%
df_final.to_csv('result2.csv')

# %%
files = glob.glob("*.xpt")

i=1
for file in files:
    if i ==1:
        df_final=pd.read_sas(file)
        
        i=i+1
    else:
        df1=pd.read_sas(file)
        print(df1)
# Out:
#          SEQN  URXUMA  URXUMS  URXUCR   URXCRS
# 0     41475.0     7.9     7.9    45.0   3978.0
# 1     41476.0     4.8     4.8    72.0   6365.0
# 2     41477.0   160.3   160.3   135.0  11934.0
# 3     41479.0     5.3     5.3   124.0  10962.0
# 4     41480.0     4.2     4.2    33.0   2917.0
# 5     41481.0    11.7    11.7   366.0  32354.0
# 6     41482.0    16.6    16.6   130.0  11492.0
# 7     41483.0     2.4     2.4    58.0   5127.0
# 8     41485.0     7.9     7.9    69.0   6100.0
# 9     41486.0     8.8     8.8    72.0   6365.0
# 10    41487.0     6.0     6.0    81.0   7160.0
# 11    41489.0     7.8     7.8    91.0   8044.0
# 12    41490.0     1.0     1.0    22.0   1945.0
# 13    41491.0    18.3    18.3    78.0   6895.0
# 14    41492.0     3.1     3.1    49.0   4332.0
# 15    41493.0    21.6    21.6    51.0   4508.0
# 16    41494.0    10.1    10.1   257.0  22719.0
# 17    41495.0     1.4     1.4    32.0   2829.0
# 18    41496.0     NaN     NaN     NaN      NaN
# ...

# %%
#last= pd.DataFrame(df_final)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6546 entries, 0 to 6545
# Data columns (total 58 columns):
# SEQN       6546 non-null float64
# WHD010     6445 non-null float64
# WHD020     6460 non-null float64
# WHQ030     6504 non-null float64
# WHQ040     6504 non-null float64
# WHD045     4361 non-null float64
# WHD050     6464 non-null float64
# WHQ060     1227 non-null float64
# WHQ070     5780 non-null float64
# WHD080A    1699 non-null float64
# WHD080B    971 non-null float64
# WHD080C    1170 non-null float64
# WHD080D    1519 non-null float64
# WHD080E    462 non-null float64
# WHD080F    273 non-null float64
# WHD080G    104 non-null float64
# WHD080H    124 non-null float64
# WHD080I    69 non-null float64
# WHD080J    149 non-null float64
# WHD080K    20 non-null float64
# WHD080L    47 non-null float64
# WHD080M    1029 non-null float64
# WHD080N    121 non-null float64
# WHD080O    684 non-null float64
# WHD080P    19 non-null float64
# ...

# %%
#from functools import reduce
#df_final = reduce(lambda left,right: pd.merge(left,right,on='SEQN', how='outer'), file)
last.shape
# Out:
# (114, 1)

# %%
print(files)
# Out:
# ['ACQ_E.XPT', 'ALB_CR_E.XPT', 'ALQ_E.XPT', 'APOB_E.XPT', 'AQQ_E.XPT', 'AUQ_E.XPT', 'AUXAR_E.XPT', 'AUXTYM_E.XPT', 'AUX_E.XPT', 'BHQ_E.XPT', 'BIOPRO_E.XPT', 'BMX_E.XPT', 'BPQ_E.XPT', 'BPX_E.XPT', 'CARB_E.XPT', 'CBC_E.XPT', 'CBQPFA_E.XPT', 'CBQPFC_E.XPT', 'CBQ_E.XPT', 'CDQ_E.XPT', 'CHLMDA_E.XPT', 'COTNAL_E.XPT', 'CRP_E.XPT', 'DBQ_E.XPT', 'DEET_E.XPT', 'DEMO_E.XPT', 'DIQ_E.XPT', 'DPQ_E.XPT', 'DUQ_E.XPT', 'DXXFEM_E.XPT', 'DXXSPN_E.XPT', 'ECQ_E.XPT', 'ENX_E.XPT', 'EPH_E.XPT', 'FASTQX_E.XPT', 'FERTIN_E.XPT', 'FOLATE_E.XPT', 'FOLFMS_E.XPT', 'FSQ_E.XPT', 'GHB_E.XPT', 'GLU_E.XPT', 'HCQ_E.XPT', 'HDL_E.XPT', 'HEPA_E.XPT', 'HEPBD_E.XPT', 'HEPB_S_E.XPT', 'HEPC_E.XPT', 'HIQ_E.XPT', 'HIV_E.XPT', 'HOQ_E.XPT', 'HPVSER_E.XPT', 'HPVSWR_E.XPT', 'HSQ_E.XPT', 'HSV_E.XPT', 'HUQ_E.XPT', 'IHG_E.XPT', 'IMQ_E.XPT', 'INQ_E.XPT', 'KIQ_P_E.XPT', 'KIQ_U_E.XPT', 'MCQ_E.XPT', 'OCQ_E.XPT', 'OGTT_E.XPT', 'OHQ_E.XPT', 'OHX_E.XPT', 'OPD_E.XPT', 'OPXFDT_E.XPT', 'OPXRET_E.XPT', 'OSQ_E.XPT', 'PAH_E.XPT', 'PAQ_E.XPT', 'PBCD
# ...

# %%
files =glob.glob(os.path.join("*.xpt"))
data=np.array([np.arrange(1,10001)]).T
x_train=pd.dataframe(data,index=range(0,10000),coloumns)

# %%
for infile in files
    df=pd.read_sas(infile)
    df['SEQN']= df['SEQN'].astype(int)
    x_train=x_train.merge(df.drop_duplicates(subset=['SEQN'], on='SEQN', how='left')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Ganga\\Desktop\\Research\\CDCDiab\\QuestData\\all'

# %%
x_train.to_csv('test.csv')
